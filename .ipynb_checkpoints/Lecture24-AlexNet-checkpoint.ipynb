# %% [markdown]
# ## 机器学习的进展
# 1. 核方法：learning with kernels
# - SVM, regularization, optimization
# - 通过核函数计算相关性
# - 凸优化问题
# - 漂亮的定理
# 2. 几何学：multiple view geometry
# - 抽取特征
# - 描述几何（多相机）
# - （非）凸优化
# - 漂亮的定理
# - 假设满足了，效果会非常好
# 3. 特征工程
# - 特征描述子：SIFT,SURF
# - 视觉词
# - 最后用
#
# ## 数据集：ImageNet
# 自然物体的彩色图片
# 大小：469 * 387
# 样本数： 1.2M
# 类数： 1000
#
# ## AlexNet
# 主要改进：
# - Dropout
# - ReLu
# - Maxpooling （相比于AvgPool,最大值大，梯度也更大，训练更容易一些）
# 是计算视觉方法论的改变：量变引起质变

# %% [markdown]
# ## 从LeNet到AlexNet：Alex的架构
# ![softmax-description](./imgs/24-1.png)
# 1. 输出部分
# - 更大的池化窗口，使用最大池化层
# - 更大的核窗口和步长，因为图片更大了
# 2. 中间部分
# - 新加了3层卷积层
# - 更多的输出通道：256（相比于LeNet的96）（kernel size = 2,pad = 2就使得输入等于输出）
# 3. 输出部分
# - 1000类输出
# - 从120增加到了4906
# 4. 更多细节
# - 激活函数从sigmoid变到了relu（减缓梯度消失）
# - 隐藏全连接层后增加了丢弃层
# - 数据增强
# 5. 复杂度

# %%
# %matplotlib inline
import torch
from torch import nn
import d2l

# %%
# 这里还是使用Fashion-MNIST数据，而不是论文中的ImageNet数据
net = nn.Sequential(
    # 这里用11*11更大的窗口去捕捉对象，stride为4以减小输出的高和宽
    nn.Conv2d(1,96,kernel_size=11, stride=4, padding=1), nn.ReLU(),
    nn.MaxPool2d(3, stride=2),
    # 这里减小卷积窗口，使用填充为2使得输入和输出的高和宽一致，且增大输出通道
    nn.Conv2d(96,256,kernel_size=5, padding=2), nn.ReLU(),
    nn.MaxPool2d(3, stride=2),
    # 使用3个连续的卷积层    
    nn.Conv2d(256,384,kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(384,384,kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(384,256,kernel_size=3, padding=1), nn.ReLU(),
    # pooling layer不减小输入的高度和宽度
    nn.MaxPool2d(3, stride=2),
    nn.Flatten(),
    # 这里的6400需要自己计算得到
    nn.Linear(6400, 4096), nn.ReLU(),
    # 用dropout来减轻过拟合
    nn.Dropout(p=0.5),
    nn.Linear(4096, 4096), nn.ReLU(),
    nn.Dropout(p=0.5),
    # 10类
    nn.Linear(4096, 10)
)

# %%
X = torch.rand(size=(1, 1, 224, 224), dtype=torch.float32)
for layer in net: # 每一层循环一次，net本身是一个iterater
    X = layer(X)
    print(layer.__class__.__name__,'output shape: \t',X.shape)
# Out:
# Conv2d output shape: 	 torch.Size([1, 96, 54, 54])
# ReLU output shape: 	 torch.Size([1, 96, 54, 54])
# MaxPool2d output shape: 	 torch.Size([1, 96, 26, 26])
# Conv2d output shape: 	 torch.Size([1, 256, 26, 26])
# ReLU output shape: 	 torch.Size([1, 256, 26, 26])
# MaxPool2d output shape: 	 torch.Size([1, 256, 12, 12])
# Conv2d output shape: 	 torch.Size([1, 384, 12, 12])
# ReLU output shape: 	 torch.Size([1, 384, 12, 12])
# Conv2d output shape: 	 torch.Size([1, 384, 12, 12])
# ReLU output shape: 	 torch.Size([1, 384, 12, 12])
# Conv2d output shape: 	 torch.Size([1, 256, 12, 12])
# ReLU output shape: 	 torch.Size([1, 256, 12, 12])
# MaxPool2d output shape: 	 torch.Size([1, 256, 5, 5])
# Flatten output shape: 	 torch.Size([1, 6400])
# Linear output shape: 	 torch.Size([1, 4096])
# ReLU output shape: 	 torch.Size([1, 4096])
# Dropout output shape: 	 torch.Size([1, 4096])
# Linear output shape: 	 torch.Size([1, 4096])
# ReLU output shape: 	 torch.Size([1, 4096])
# ...

# %%
batch_size =128
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size,resize = 224)

# %%
lr, num_epochs = 0.01, 10 # 学习率，
d2l.train_ch6(net, train_iter, test_iter, num_epochs,lr, d2l.try_gpu())
# AlexNet虽然比LeNet计算量大，但是对GPU的使用率更高，所以速度也不慢
# Out:
# training on cpu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-3be23cbb321a> in <module>
#       1 lr, num_epochs = 0.01, 10 # 学习率，
# ----> 2 d2l.train_ch6(net, train_iter, test_iter, num_epochs,lr, d2l.try_gpu())
#       3 # AlexNet虽然比LeNet计算量大，但是对GPU的使用率更高，所以速度也不慢
#
# ~/Desktop/my_own_practice/basic-AI-exercise/d2l.py in train_ch6(net, train_iter, test_iter, num_epochs, lr, device)
#    2836             optimizer.zero_grad()
#    2837             X, y = X.to(device), y.to(device)
# -> 2838             y_hat = net(X)
#    2839             l = loss(y_hat, y)
#    2840             l.backward()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
# ...
